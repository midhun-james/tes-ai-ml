# %%
from google.colab import userdata
import os
os.environ['GOOGLE_API_KEY']=userdata.get('GOOGLE_API_KEY')

# %%
pip install -q agno
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.0 MB/s eta 0:00:00

# %%
import pandas as pd

df = pd.read_csv('kpi.csv', parse_dates=['timestamp'])
df['hour'] = df['timestamp'].dt.hour

# Global storage for DataFrame
_dataframe_store = {'df': None}

# %%
from agno.tools import tool

@tool
def get_all_cells_prb_timeseries() -> dict:
    """
    Extracts Downlink PRB utilization values for ALL cells.

    Returns:
        Dictionary containing:
        - all_cells: list of all cell IDs
        - cells_data: dict with each cell's hourly PRB utilization
        - summary_stats: overall statistics
    """
    df = _dataframe_store['df']

    if df is None:
        return {"error": "No DataFrame loaded"}

    all_cells = df['cell_id'].unique().tolist()
    cells_data = {}

    for cell_id in all_cells:
        subset = df[df["cell_id"] == cell_id]

        if not subset.empty:
            prb_by_hour = subset.groupby("hour")["Downlink PRB Utilization"].mean().to_dict()

            cells_data[str(cell_id)] = {
                "prb_by_hour": {int(k): round(float(v), 2) for k, v in prb_by_hour.items()},
                "avg_prb": round(float(subset["Downlink PRB Utilization"].mean()), 2),
                "max_prb": round(float(subset["Downlink PRB Utilization"].max()), 2),
                "min_prb": round(float(subset["Downlink PRB Utilization"].min()), 2)
            }

    # Calculate summary statistics
    summary_stats = {
        "total_cells": len(all_cells),
        "overall_avg_prb": round(float(df["Downlink PRB Utilization"].mean()), 2),
        "overall_max_prb": round(float(df["Downlink PRB Utilization"].max()), 2),
        "overall_min_prb": round(float(df["Downlink PRB Utilization"].min()), 2)
    }

    return {
        "all_cells": all_cells,
        "cells_data": cells_data,
        "summary_stats": summary_stats
    }

# Store the DataFrame
_dataframe_store['df'] = df

# %%
import json
@tool
def save_threshold_recommendations(thresholds_json: str) -> dict:
    """
    Saves the threshold recommendations to a structured format.

    Args:
        thresholds_json: JSON string containing threshold recommendations.
                        Format: [{"cell_id": "Cell_01", "threshold": 40, "rationale": "..."}, ...]

    Returns:
        Confirmation message
    """
    try:
        thresholds = json.loads(thresholds_json)

        # Save to global store
        threshold_df = pd.DataFrame(thresholds)
        _dataframe_store['thresholds'] = threshold_df

        # Save to CSV
        threshold_df.to_csv('cell_thresholds.csv', index=False)

        return {
            "status": "success",
            "message": f"Saved {len(thresholds)} threshold recommendations",
            "file": "cell_thresholds.csv"
        }
    except Exception as e:
        return {
            "status": "error",
            "message": str(e)
        }

# %%
# Create agent with enhanced instructions
from agno.agent import Agent
from agno.models.google import Gemini

prb_agent = Agent(
    name="PRB Network Optimization Agent",
    role="Telecom Network PRB utilization expert and optimization specialist",
    model=Gemini(
        id="gemini-2.0-flash",
        api_key=userdata.get('GOOGLE_API_KEY')
    ),
    tools=[get_all_cells_prb_timeseries,save_threshold_recommendations],
    instructions="""
    You are an expert telecom network optimizer analyzing PRB utilization across all cells.

    Your task:
    1) Call get_all_cells_prb_timeseries() to retrieve data for ALL cells

    2) For EACH cell, analyze:
       - Peak PRB hours (highest utilization periods)
       - Low traffic hours (lowest utilization periods)
       - Average daily utilization pattern
       - Congestion indicators (PRB > 70% indicates congestion)
       - Unusual spikes or anomalies

    3) Determine optimal THRESHOLD values:
       - Calculate a PRB threshold for each cell below which it can be switched off
       - Consider: minimum PRB values, traffic patterns, redundancy requirements
       - Thresholds should typically be between 10-30% PRB utilization
       - Account for time-of-day patterns (e.g., nighttime vs daytime)

    4) Provide a comprehensive report with:
       - Summary of all cells analyzed
       - Individual cell analysis with peak/low hours
       - **CRITICAL**: A table/list showing each cell with its recommended switch-off threshold
       - Optimization recommendations (load balancing, cell switching strategies)
       - Potential energy savings estimates

    5) Format the threshold recommendations clearly as:
       Cell ID | Recommended Threshold (%) | Rationale

    6) **IMPORTANT**: After your analysis, call save_threshold_recommendations() with a JSON array containing:
       [
         {"cell_id": "Cell_01", "threshold": 40, "rationale": "High utilization..."},
         {"cell_id": "Cell_02", "threshold": 15, "rationale": "Low utilization..."},
         ...
       ]
    Be specific with numerical thresholds for each cell based on the actual data patterns.
    Always call save_threshold_recommendations() to store the structured data
    """,
    markdown=True,
)

# Run the agent

# %%
result = prb_agent.run(
    """Analyze PRB utilization for all cells in the network.

    For each cell, determine:
    1. Traffic patterns and peak/low hours
    2. Optimal PRB threshold value for switching off the cell during low utilization
    3. Provide a clear table with cell IDs and their recommended thresholds
    4. Analyzis of each cells should be displayed seperately and include insights and suggestions for them also
    4. After your analysis, save the thresholds using save_threshold_recommendations().
    Be specific with the threshold values based on the actual data."""
)

print(result.content)
# Out:
# Okay, I have analyzed the PRB utilization data for all ten cells. Here's a breakdown of my findings, including recommended switch-off thresholds:
#
# **Summary of Analysis:**
#
# The network exhibits a range of PRB utilization patterns. Some cells (e.g., Cell_01, Cell_05) show consistently higher utilization, while others (e.g., Cell_02, Cell_03, Cell_04, Cell_08) have lower average utilization and significant periods of very low usage. Most cells show a typical diurnal pattern, with peak usage in the late afternoon/early evening and lower usage overnight.
#
# **Individual Cell Analysis:**
#
# **Cell_01:**
# *   **Traffic Pattern:** Relatively high and consistent utilization throughout the day. Peak hours are 17:00-21:00. Low hours are 0:00-5:00, but still relatively high.
# *   **Congestion:** Average PRB is high (52.15%), but max PRB is 68.74%.
# *   **Recommendation:** Due to the consistently high utilization, switching off Cell_01 is not recommended. Load balancing to neighboring cells during peak hours might be beneficial.
# *   **Recommended Threshold:** 40% (To ensure the cell is only temporary switched off if PRB drops significantly)
#
# **Cell_02:**
# *   **Traffic Pattern:** Lower utilization compared to Cell_01. Peak hours are 17:00-21:00. Lowest hours are 0:00-5:00.
# *   **Congestion:** No significant congestion. Max PRB is 42.13%.
# *   **Recommendation:** Suitable for switch-off during low-traffic hours.
# *   **Recommended Threshold:** 15% (Below the average during the cell's lowest hours)
#
# **Cell_03:**
# *   **Traffic Pattern:** Similar to Cell_02, with low overall utilization. Peak hours are 17:00-21:00. Lowest hours are 0:00-5:00.
# *   **Congestion:** No significant congestion. Max PRB is 40.19%.
# *   **Recommendation:** Suitable for switch-off during low-traffic hours.
# *   **Recommended Threshold:** 15% (Similar reasoning to Cell_02)
#
# **Cell_04:**
# *   **Traffic Pattern:** Very similar to Cell_03 and Cell_02. Peak hours are 17:00-21:00. Lowest hours are 0:00-5:00. Minimum PRB reaches 0.
# *   **Congestion:** No significant congestion. Max PRB is 42.59%.
# *   **Recommendation:** Very suitable for switch-off during low-traffic hours.
# *   **Recommended Threshold:** 10% (Can be switched off aggressively during low hours due to very low min PRB)
#
# **Cell_05:**
# *   **Traffic Pattern:** High utilization, similar to Cell_01. Peak hours are 17:00-21:00. Low hours are 0:00-5:00, but still relatively high.
# *   **Congestion:** Average PRB is high (49.85%), and max PRB is 68.9%.
# *   **Recommendation:** Due to the consistently high utilization, switching off Cell_05 is not recommended. Load balancing might be considered.
# *   **Recommended Threshold:** 40% (Similar to Cell_01)
#
# **Cell_06:**
# *   **Traffic Pattern:** Moderate utilization. Peak hours are 17:00-21:00. Lowest hours are 0:00-5:00.
# *   **Congestion:** No significant congestion. Max PRB is 42.94%.
# *   **Recommendation:** Suitable for switch-off during low-traffic hours.
# *   **Recommended Threshold:** 20% (A bit higher than Cell_02/03/04 due to slightly higher average utilization)
#
# **Cell_07:**
# *   **Traffic Pattern:** Moderate to high utilization. Peak hours are 17:00-21:00. Utilization is fairly consistent.
# *   **Congestion:** Max PRB is 59.33%.
# *   **Recommendation:** Switch-off might be possible, but the threshold should be chosen carefully.
# *   **Recommended Threshold:** 30%
#
# **Cell_08:**
# *   **Traffic Pattern:** Low utilization, similar to Cell_02/03/04. Peak hours are 17:00-21:00. Lowest hours are 0:00-5:00. Minimum PRB reaches 0.
# *   **Congestion:** No significant congestion. Max PRB is 40.33%.
# *   **Recommendation:** Very suitable for switch-off during low-traffic hours.
# *   **Recommended Threshold:** 10% (Similar to Cell_04)
#
# **Cell_09:**
# *   **Traffic Pattern:** Moderate utilization. Peak hours are 17:00-21:00.
# *   **Congestion:** Max PRB is 57.91%.
# *   **Recommendation:** Switch-off is possible during low hours.
# *   **Recommended Threshold:** 25%
#
# **Cell_10:**
# *   **Traffic Pattern:** Moderate utilization, similar to Cell_09. Peak hours are 17:00-21:00.
# *   **Congestion:** Max PRB is 57.54%.
# *   **Recommendation:** Switch-off is possible during low hours.
# *   **Recommended Threshold:** 25% (Similar to Cell_09)
#
# **Recommended Switch-Off Thresholds:**
#
# | Cell ID   | Recommended Threshold (%) | Rationale                                                                 |
# | :-------- | :------------------------ | :------------------------------------------------------------------------ |
# | Cell_01   | 40                        | High utilization; switch-off not generally recommended.                   |
# | Cell_02   | 15                        | Low utilization, suitable for switch-off during off-peak hours.          |
# | Cell_03   | 15                        | Low utilization, suitable for switch-off during off-peak hours.          |
# | Cell_04   | 10                        | Very low utilization, aggressively switch-off during off-peak.           |
# | Cell_05   | 40                        | High utilization; switch-off not generally recommended.                   |
# | Cell_06   | 20                        | Moderate utilization, switch-off during off-peak hours.                   |
# | Cell_07   | 30                        | Moderate to high utilization, careful switch-off threshold.               |
# | Cell_08   | 10                        | Very low utilization, aggressively switch-off during off-peak.           |
# | Cell_09   | 25                        | Moderate utilization, switch-off during off-peak hours.                   |
# | Cell_10   | 25                        | Moderate utilization, switch-off during off-peak hours.                   |
#
# **Optimization Recommendations:**
#
# 1.  **Load Balancing:** For Cell_01 and Cell_05, investigate load balancing options to distribute traffic to neighboring cells, especially during peak hours. This could involve adjusting cell parameters or deploying additional capacity in adjacent areas.
# 2.  **Cell Switching Strategies:** Implement a cell switching strategy based on the recommended thresholds. This could be automated using a network management system that monitors PRB utilization and switches off cells when their utilization falls below the threshold for a sustained period.
# 3.  **Parameter Optimization:** Fine-tune cell parameters (e.g., transmit power, antenna tilt) to optimize coverage and capacity, potentially reducing overall PRB utilization.
#
# **Potential Energy Savings Estimates:**
#
# The potential energy savings from switching off cells during low-traffic hours could be significant. Cells 02, 03, 04, 06, 08, 09 and 10 are good candidates. Actual savings will depend on the power consumption of each cell and the duration of the switch-off periods. A detailed power consumption model would be needed to provide a precise estimate. However, a rough estimate could be obtained by assuming a certain percentage of energy savings per cell switched off (e.g., 30-50%) and multiplying that by the number of cells switched off and the duration of the switch-off periods.
#
# I have saved the threshold recommendations to a structured format. The analysis is complete.

# %%
threshold_df=pd.read_csv('cell_thresholds.csv')
threshold_df.head(10)
# Out:
#    cell_id  threshold                                          rationale
# 0  Cell_01         40  High utilization; switch-off not generally rec...
# 1  Cell_02         15  Low utilization, suitable for switch-off durin...
# 2  Cell_03         15  Low utilization, suitable for switch-off durin...
# 3  Cell_04         10  Very low utilization, aggressively switch-off ...
# 4  Cell_05         40  High utilization; switch-off not generally rec...
# 5  Cell_06         20  Moderate utilization, switch-off during off-pe...
# 6  Cell_07         30  Moderate to high utilization, careful switch-o...
# 7  Cell_08         10  Very low utilization, aggressively switch-off ...
# 8  Cell_09         25  Moderate utilization, switch-off during off-pe...
# 9  Cell_10         25  Moderate utilization, switch-off during off-pe...

# %%
def decision(predicted_df: pd.DataFrame, threshold_df: pd.DataFrame) -> dict:
      merged = predicted_df.merge(threshold_df, on="cell_id", how="inner")
      merged["switch_off"] = merged.apply(
        lambda row: row["predicted_prb"] < row["threshold"], axis=1
    )
      switch_off_cells = merged[merged["switch_off"]]["cell_id"].tolist()

      return {
          "switch_off_candidates": switch_off_cells,}

# %%
threshold_df=pd.read_csv('cell_thresholds.csv')
predicted_df=pd.read_csv('predicted_prb_utilization.csv')
predicted_df["cell_id"] = predicted_df["cell_id"].str.lower().str.strip()
threshold_df["cell_id"] = threshold_df["cell_id"].str.lower().str.strip()
decision(predicted_df,threshold_df)
# Out:
# {'switch_off_candidates': []}
